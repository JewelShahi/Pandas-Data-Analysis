# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = '/content/drive/MyDrive/DataSets/Words/words.csv'
df = pd.read_csv(file_path)
df = df.set_index('words') # removes the indexes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 370103 entries, a to zwitterionic
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   count   370103 non-null  int64
#  1   value   370103 non-null  int64
# dtypes: int64(2)
# memory usage: 8.5+ MB

# %%
df
# Out:
#               count  value
# words
# a                 1      1
# aa                2      2
# aaa               3      3
# aah               3     10
# aahed             5     19
# ...             ...    ...
# zwinglianism     12    156
# zwinglianist     12    163
# zwitter           7    121
# zwitterion       10    159
# zwitterionic     12    171
#
# [370103 rows x 2 columns]

# %%
df.shape
# Out:
# (370103, 2)

# %%
df["value"].max()
# Out:
# 390

# %%
df.describe()
# Out:
#                count          value
# count  370103.000000  370103.000000
# mean        9.442507     110.954578
# std         2.916429      40.745370
# min         1.000000       1.000000
# 25%         7.000000      82.000000
# 50%         9.000000     107.000000
# 75%        11.000000     136.000000
# max        31.000000     390.000000

# %%
df.loc["aahed", "value"]
# Out:
# np.int64(19)

# %%
df.loc["aahed"]
# Out:
# count     5
# value    19
# Name: aahed, dtype: int64

# %%
df.loc[[
    "pinfish",
    "superheterodyne",
    "glowing",
    "bold",
    "enfold"
], "value"]
# Out:
# words
# pinfish             81
# superheterodyne    198
# glowing             87
# bold                33
# enfold              56
# Name: value, dtype: int64

# %%
df.loc[[
    "pinfish",
    "superheterodyne",
    "glowing",
    "bold",
    "enfold"
]]
# Out:
#                  count  value
# words
# pinfish              7     81
# superheterodyne     15    198
# glowing              7     87
# bold                 4     33
# enfold               6     56

# %%
df.sort_values(by=["value"], ascending=False)
# Out:
#                                  count  value
# words
# hydroxydesoxycorticosterone         27    390
# trinitrophenylmethylnitramine       29    389
# hydroxydehydrocorticosterone        28    377
# cyclotrimethylenetrinitramine       29    362
# dichlorodiphenyltrichloroethane     31    348
# ...                                ...    ...
# aaa                                  3      3
# ab                                   2      3
# aa                                   2      2
# b                                    1      2
# a                                    1      1
#
# [370103 rows x 2 columns]

# %%
df[df["value"] == 317]
# Out:
#                           count  value
# words
# thyroparathyroidectomize     24    317

# %%
df.value.describe()
# Out:
# count    370103.000000
# mean        110.954578
# std          40.745370
# min           1.000000
# 25%          82.000000
# 50%         107.000000
# 75%         136.000000
# max         390.000000
# Name: value, dtype: float64

# %%
df.value.value_counts()
# Out:
# value
# 102    3787
# 97     3783
# 100    3770
# 93     3760
# 98     3750
#        ...
# 297       1
# 362       1
# 291       1
# 304       1
# 348       1
# Name: count, Length: 320, dtype: int64

# %%
df.loc[df.value == 102]
# Out:
#               count  value
# words
# abashments       10    102
# abbroachment     12    102
# abmodality       10    102
# abnegators       10    102
# abrogation       10    102
# ...             ...    ...
# zoogamy           7    102
# zoolite           7    102
# zoologic          8    102
# zoophobe          8    102
# zoothecia         9    102
#
# [3787 rows x 2 columns]

# %%
df.loc[df.value == 274].sort_values(by=["count"], ascending=True)
# Out:
#                         count  value
# words
# unvoluptuousness           16    274
# hyperlustrousness          17    274
# ventrohysteropexy          17    274
# nonsymphoniousness         18    274
# uncontemptuousness         18    274
# unproportionateness        19    274
# nondisputatiousness        19    274
# anthropophysiography       20    274
# noncontemporaneously       20    274
# overrepresentatively       20    274
# psychophysiologically      21    274
# counterpronunciamento      21    274
# overimpressionableness     22    274

# %%
df.loc[
    (df["value"] == 274) &
    (df["count"] == 16)
]

# df.loc[df["value"] == 274, "count"].min()
# Out:
#                   count  value
# words
# unvoluptuousness     16    274

# %%
df["ratio"] = df["value"]/df["count"]
df
# Out:
#               count  value      ratio
# words
# a                 1      1   1.000000
# aa                2      2   1.000000
# aaa               3      3   1.000000
# aah               3     10   3.333333
# aahed             5     19   3.800000
# ...             ...    ...        ...
# zwinglianism     12    156  13.000000
# zwinglianist     12    163  13.583333
# zwitter           7    121  17.285714
# zwitterion       10    159  15.900000
# zwitterionic     12    171  14.250000
#
# [370103 rows x 3 columns]

# %%
df.sort_values(by="ratio", ascending=False)
# Out:
#        count  value      ratio
# words
# z          1     26  26.000000
# xyz        3     75  25.000000
# y          1     25  25.000000
# wuzzy      5    121  24.200000
# wy         2     48  24.000000
# ...      ...    ...        ...
# baa        3      4   1.333333
# aba        3      4   1.333333
# aa         2      2   1.000000
# aaa        3      3   1.000000
# a          1      1   1.000000
#
# [370103 rows x 3 columns]

# %%
df.loc[df["ratio"] == df["ratio"].max()]
# Out:
#        count  value  ratio
# words
# z          1     26   26.0

# %%
df.query("ratio == 10").shape
# Out:
# (5558, 3)

# %%
df.query("ratio == 10").sort_values(by="value", ascending=False)
# Out:
#                           count  value  ratio
# words
# electrocardiographically     24    240   10.0
# pathologicoanatomical        21    210   10.0
# anatomicopathological        21    210   10.0
# hypsidolichocephalic         20    200   10.0
# anatomicochirurgical         20    200   10.0
# ...                         ...    ...    ...
# mg                            2     20   10.0
# hl                            2     20   10.0
# cq                            2     20   10.0
# gm                            2     20   10.0
# j                             1     10   10.0
#
# [5558 rows x 3 columns]

# %%
df.loc[df["ratio"] == 10, "value"].max()
# Out:
# 240

# %%
df.query("value == 260").sort_values(by="count", ascending=True)
# Out:
#                         count  value      ratio
# words
# nonsynonymously            15    260  17.333333
# hydroxytryptamine          17    260  15.294118
# gastrohysteropexy          17    260  15.294118
# hyperobtrusiveness         18    260  14.444444
# noninstructiveness         18    260  14.444444
# nonadventurousness         18    260  14.444444
# psychophysiologist         18    260  14.444444
# overobsequiousness         18    260  14.444444
# unvituperativeness         18    260  14.444444
# hyperridiculousness        19    260  13.684211
# nonsubconsciousness        19    260  13.684211
# extraconstitutional        19    260  13.684211
# dihydrostreptomycin        19    260  13.684211
# hypsiprymnodontinae        19    260  13.684211
# scleroconjunctivitis       20    260  13.000000
# hexosemonophosphoric       20    260  13.000000
# thermophosphorescent       20    260  13.000000
# philosophicoreligious      21    260  12.380952
# ...

# %%
# df.query("count > count.mean()")
# or if i want to add external var like x in the query
## do this -> `df.query("count > @mean_count_var")`, where `mean_count_var = df["count"].mean()`
df.loc[df["count"] > df["count"].mean()]
# Out:
#               count  value      ratio
# words
# aardwolves       10    120  12.000000
# abacination      11     89   8.090909
# abacterial       10     72   7.200000
# abactinally      11    100   9.090909
# abalienate       10     70   7.000000
# ...             ...    ...        ...
# zwieselite       10    133  13.300000
# zwinglianism     12    156  13.000000
# zwinglianist     12    163  13.583333
# zwitterion       10    159  15.900000
# zwitterionic     12    171  14.250000
#
# [167515 rows x 3 columns]
